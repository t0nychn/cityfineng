# %%
from mc import *

# %%
gbm_mc = mc_gbm(r=0.1, sig=0.2, paths=500,steps=500)
gbm_mc.plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
gbm_mc.iloc[-1].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
ou_mc = mc_ou(sig=0.2, theta=0.7, paths=500,steps=500)
ou_mc.plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
ou_mc.iloc[-1].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
abm_mc = mc_abm(r=0.1, sig=0.2, paths=500,steps=500)
abm_mc.plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
abm_mc.iloc[-1].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
mc_abm(S0=0, r=0.1, sig=0.2, paths=50,steps=50).plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
mc_ou(S0=0, sig=0.5, theta=0.7, paths=50,steps=50).plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
mc_gbm(S0=0.1, r=-0.5, sig=0.8, paths=50,steps=50).plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
mc_abm(S0=0.1, r=-0.5, sig=0.8, paths=50,steps=50).plot(legend=False)
# Out:
# <AxesSubplot:>
